# %% [markdown]
# #Transfer Learning with Med MNIST.
#
# In this assignment you will use transfer learning to train a model of your choice on a sub-dataset from the [MedMNIST datasets](https://medmnist.com/). ![](https://github.com/tonyscan6003/etivities/blob/main/medmnist.JPG?raw=true)
#
# * The [MedMNIST package](https://github.com/MedMNIST/MedMNIST/blob/main/examples/getting_started.ipynb) allows the data to be imported directly as a pytorch dataset.
#
# * You may select any of the datasets using Multi-class/binary classification. The goal is to acheve accuracy levels comparable to the benchmark results shown on the medmnist site. Dataloading for pytorch is setup in the notebook, you wil need to modify the code slightly depending on your dataset of choice.
#
# * Some datasets use black and white images, so you will need to [at least concatenate](https://towardsdatascience.com/transfer-learning-on-greyscale-images-how-to-fine-tune-pretrained-models-on-black-and-white-9a5150755c7a) the input image channels (to 3 channels) for compatibility with the models pre-trained on imageNet.
#
# * Some of the MedMNIST datasets don't contain too much data so Data augmentation may be essentila essential to avoid overfitting. In pytorch data augmentation is performed using the [transforms.v2](https://pytorch.org/vision/main/transforms.html) modules.
#
# * In this notebook: You will need to import a model, and perform training. Tranfer Learning for computer vision is detailed [here](https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html)
#
# * [Tensorboard can be imported](https://pytorch.org/tutorials/beginner/introyt/tensorboardyt_tutorial.html) to display results.
#
# * Please only include one example of transfer learning in the submitted notebook. Making sure training curves/results are clearly visible. If you have trained additional transfer learning models (i.e. that were less successful) please add this as a table or report at the end of the notebook and/or in your final forum post.

# %% [markdown]
# # 1. Install & Import Packages

# %%
# !pip install medmnist
# !pip install torchinfo
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from medmnist) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from medmnist) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from medmnist) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from medmnist) (0.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from medmnist) (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from medmnist) (11.3.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from medmnist) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from medmnist) (0.23.0+cu126)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->medmnist) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->medmnist) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->medmnist) (3.0.3)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: fire, medmnist
# Successfully installed fire-0.7.1 medmnist-3.0.2
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
from torch import nn
from torchvision import datasets, models
from torchvision.transforms import ToTensor, v2, Pad, Grayscale
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import numpy as np

# %% [markdown]
# ## 2. Setup & Import Dataset
# The [MedMNSIT](https://medmnist.com/) package (imported above) makes available several medical datasets available to access.
#
# You can change the `data_flag` variable (dataset names are all lower case letters) to the dataset of your choice (Take care to note the parameters e.g. number of input channels below that will affect your model)

# %%
import medmnist
from medmnist import INFO, Evaluator

data_flag = 'chestmnist'
download = True

BATCH_SIZE = 64

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

print('Type of Machine Learning Task = ',task)
print('Number of Input Data Channels = ',n_channels)
print('Number of Classes = ',n_classes)
print('The batch size for this dataset will be = ',BATCH_SIZE)

DataClass = getattr(medmnist, info['python_class'])
# Out:
# Type of Machine Learning Task =  multi-label, binary-class
# Number of Input Data Channels =  1
# Number of Classes =  14
# The batch size for this dataset will be =  64

# %% [markdown]
# Transforms:
# You can update the functions below with appropriate transforms for your particular use case.
#
# * As well as being suitable for data augmention for image classification, the transforms.v2 package of torchvision extends transforms for object detection and segmentation tasks. An illustration of the transforms is shown [here](https://pytorch.org/vision/main/auto_examples/transforms/plot_transforms_illustrations.html#sphx-glr-auto-examples-transforms-plot-transforms-illustrations-py).
# * Normalisation based on ImageNet parameters is included already. This should be used with all models pre-trained on ImageNet

# %%
train_transforms = v2.Compose([
    v2.Resize((224,224)),
    v2.ToImage(), # v2 expects an "image/PIL"
    v2.RandomHorizontalFlip(),
    v2.ToDtype(torch.float32, scale=True),
    #ToTensor(), replaced with v2.ToImage
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


test_transforms = v2.Compose([
    v2.Resize((224, 224)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    #ToTensor(),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %% [markdown]
# Setup your Medmnist dataset.
# * The convolution part of pre-trained networks (such as resnet) are compatable with any size input image. However they were trained on 224 x 224 size images, with early layers finding small scale features and deeper layers finding large scale features.
# * For this transfer learning application to medical data, the gap between the original ImageNet domain and the medical images is wide. Therefore the size/scale of the input images is less important, however in general we would expect better performance with the larger input images (as they contain more features at different scales).
# * You can add the `size=224` parameter to the dataset object calls, to load full size images. Only do this once you are confident in your training methodology (or if the dataset is small), as training with full size images will take longer.

# %%
# using as_rgb = True to multiply the channels and make the grayscale, 1 channel picture a 3 channel one.
# Download training data from open datasets.
train_dataset = DataClass(split='train', transform=train_transforms, download=download, size=224, mmap_mode='r', as_rgb=True)
test_dataset = DataClass(split='test', transform=test_transforms, download=download, size=224, mmap_mode='r', as_rgb=True)
val_dataset = DataClass(split='val', transform=test_transforms, download=download, size=224, mmap_mode='r', as_rgb=True)
# Out:
# 100%|██████████| 3.89G/3.89G [04:40<00:00, 13.8MB/s]

# %% [markdown]
# The `Dataset` is passed as an argument to `DataLoader`. This wraps an
# iterable over the dataset, and supports automatic batching, sampling,
# shuffling and multiprocess data loading.

# %%
# Create data loaders.
train_dataloader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(dataset=val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 3, 224, 224])
# Shape of y: torch.Size([64, 14]) torch.int64

# %% [markdown]
# Plot some example augmented images
#
# 1.   List item
# 2.   List item

# %%
# Output next batch from dataloader
dataiter = iter(train_dataloader)
image_batch, labels_batch = next(dataiter)

# Use matplotlib to plot a sample of images

i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:
  disp_image =  torch.permute(image,(1,2,0)).numpy() # return image to cpu for display and permute to channels last
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  disp_image = std * disp_image + mean
  disp_image = np.clip(disp_image, 0, 1)
  axarr[i].imshow(disp_image[:,:,:])
  axarr[i].axis("off")
  axarr[i].set_title(labels_batch[i].numpy(),fontsize='small')
  i = i+1

# %% [markdown]
# # 3. Define Transfer Learning model
# Pytorch has an inbuilt [models package](https://pytorch.org/vision/stable/models.html) that allows loading of popular models with pre-trained weights.
#
# * We want to add an additional classifier stage (to the output of the network). How to setup the [model is detailed here](https://discuss.pytorch.org/t/load-only-a-part-of-the-network-with-pretrained-weights/88397/2).
# * This additional classifier may just be a single layer or a cascade of fully connected layers with dropout.
# * Note that the number of parameters in the convolutional part of the model will be same no what the input size is set to. However the output feature map size will vary with input image size (small for small image, large for large image). This means the number of parameters in the additional classifier will change depending on input image size.

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision.models import resnet18, ResNet18_Weights

# Planning to use RESNET 50 later but using 18 since it is lightweight to get started
weights = ResNet18_Weights.DEFAULT # ResNet50_Weights.DEFAULT
model = resnet18(weights=weights) #resnet50
print(f"Final Layer of the pretrained model: {model.fc}")
# Plug in my (Chestmnist (14 labels)) data with a Linear layer
model.fc = nn.Linear(model.fc.in_features, n_classes)
# Perhaps add Dropout ?
print(f"New final layer: {model.fc}")
model = model.to(device)

loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Out:
# Final Layer of the pretrained model: Linear(in_features=512, out_features=1000, bias=True)
# New final layer: Linear(in_features=512, out_features=14, bias=True)

# %% [markdown]
# # 4. Optimisation & Training Loop
#
# Define a training loop that prints the loss from the training and validation set at least every epoch.
# * You may choose to make the validation loss calculations more frequent so you can ensure training is progressing satisfactorily (especially with larger datasets).
#
# * You can use tensorboard to visualise the [loss curves](https://pytorch.org/docs/stable/tensorboard.html))
#
# * For multi-class classification classification problem we will use the  [CrossEntropy loss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html). In this pytorch function, the input is the un-normalised logit value.
#
# * You may  have to use [torch.squeeze](https://pytorch.org/docs/stable/generated/torch.squeeze.html) to reduce the dimensionality of the label tensor before passing it to the loss function (this due to how the dataset is configured and the loss will only accept 0D or 1D inputs)

# %% [markdown]
# Initialise Tensorboard (use of tensorboard in colab notebooks is [detailed here](https://colab.research.google.com/github/tensorflow/tensorboard/blob/master/docs/tensorboard_in_notebooks.ipynb)). A [Pytorch tutorial](https://pytorch.org/tutorials/beginner/introyt/tensorboardyt_tutorial.html) shows how to setup the training and validation loop with pytorch.

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter('runs')

# %%
n_iter = 100
n_epochs = 10

train_size = len(train_dataloader.dataset)
val_size = len(val_dataloader.dataset)
num_batches_validation = len(val_dataloader)
num_batches_train = len(train_dataloader)
print(f"train_size: {train_size}, val_size: {val_size}, num_batches_validation: {num_batches_validation}")
# Out:
# train_size: 78468, val_size: 11219, num_batches_validation: 176

# %%
for epoch in range(n_epochs):
    model.train()
    running_loss = 0.0

    # Keep track of label wise accuracy:
    running_correct_labels = 0
    running_total_labels = 0
    running_batches = 0
    # TODO: Maybe adjust batch size ?
    for i, (inputs, labels) in enumerate(train_dataloader, 0):
        inputs = inputs.to(device)
        labels = labels.to(device).float()

        # forward
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # maybe add a scheduler here:scheduler.step()

        # accumulate training loss
        running_loss += loss.item()
        running_batches += 1

        # calc accuracy - per label since 1 image has 14 labels and each label is a prediction - 1 image can contain multiple diseases (1s)
        probs = torch.sigmoid(outputs)           # Convert logits [.6,-1.1,2,0,...] to probabilities 0-1
        #if (i==0):
        #  print(f"probs: {probs}")
        #  print(f"probs shape: {probs.shape}")
        preds = (probs > 0.5).float()

        running_correct_labels += (preds == labels).sum().item() #correct predictions
        running_total_labels += labels.numel()   # all the labes in the batch = batch_size * n_classes

        # run validation and update tensorboard
        if (i % n_iter == n_iter - 1):
            model.train(False)
            val_running_loss = 0.0
            val_correct_labels = 0
            val_total_labels = 0

            with torch.no_grad():
                for vinputs, vlabels in val_dataloader:
                    vinputs = vinputs.to(device)
                    vlabels = vlabels.to(device).float()

                    voutputs = model(vinputs)
                    vloss = loss_fn(voutputs, vlabels)
                    val_running_loss += vloss.item()

                    vprobs = torch.sigmoid(voutputs)
                    vpreds = (vprobs > 0.5).float()
                    val_correct_labels += (vpreds == vlabels).sum().item()
                    val_total_labels += vlabels.numel()

            model.train(True)   # Turning train mode on

            # average over training batches
            avg_loss = running_loss / running_batches #Total Loss / number of batches
            train_label_acc = 100.0 * running_correct_labels / running_total_labels

            avg_vloss = val_running_loss / num_batches_validation
            val_label_acc = 100.0 * val_correct_labels / val_total_labels

            # current learning rate - will add a scheduler after more experiments
            current_lr = optimizer.param_groups[0]["lr"]

            print(f"Epoch {epoch+1}/{n_epochs}, Batch {i+1}")
            print(f"Training: Loss {avg_loss:.3f}, Accuracy {train_label_acc:>8f}%")
            print(f"Validation: Loss {avg_vloss:.3f}, Accuracy {val_label_acc:>8f}%")
            print(f"Learning Rate: {current_lr:.7f}\n")

            # Log for TensorBoard
            writer.add_scalars(
                'Loss',
                {'Training Loss': avg_loss, 'Validation Loss': avg_vloss},
                epoch * len(train_dataloader) + i
            )
            writer.add_scalars(
                'Accuracy',
                {'Training Accuracy': train_label_acc, 'Validation Accuracy': val_label_acc},
                epoch * len(train_dataloader) + i
            )

            running_loss = 0.0
            running_total_labels = 0
            running_correct_labels = 0
            running_batches = 0

print(f" Optimizer used: {optimizer.__class__.__name__}")
print("Finished Training")
writer.flush()
# Out:
# Epoch 1/10, Batch 100
# Training: Loss 0.160, Accuracy 94.888393%
# Validation: Loss 0.161, Accuracy 94.949894%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 200
# Training: Loss 0.160, Accuracy 94.929688%
# Validation: Loss 0.162, Accuracy 94.970904%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 300
# Training: Loss 0.162, Accuracy 94.857143%
# Validation: Loss 0.157, Accuracy 94.970267%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 400
# Training: Loss 0.155, Accuracy 95.046875%
# Validation: Loss 0.159, Accuracy 94.918697%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 500
# Training: Loss 0.159, Accuracy 94.860491%
# Validation: Loss 0.161, Accuracy 94.725784%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 600
# Training: Loss 0.162, Accuracy 94.797991%
# Validation: Loss 0.158, Accuracy 94.959444%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 700
# Training: Loss 0.160, Accuracy 94.862723%
# Validation: Loss 0.159, Accuracy 94.925700%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 800
# Training: Loss 0.157, Accuracy 94.941964%
# Validation: Loss 0.165, Accuracy 94.898960%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 900
# Training: Loss 0.157, Accuracy 94.965402%
# Validation: Loss 0.159, Accuracy 94.862033%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 1000
# Training: Loss 0.160, Accuracy 94.781250%
# Validation: Loss 0.159, Accuracy 94.939070%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 1100
# Training: Loss 0.157, Accuracy 94.935268%
# Validation: Loss 0.158, Accuracy 94.915513%
# Learning Rate: 0.0010000
#
# Epoch 1/10, Batch 1200
# Training: Loss 0.156, Accuracy 94.957589%
# Validation: Loss 0.158, Accuracy 94.902780%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 100
# Training: Loss 0.155, Accuracy 94.944196%
# Validation: Loss 0.157, Accuracy 94.883043%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 200
# Training: Loss 0.152, Accuracy 95.056920%
# Validation: Loss 0.157, Accuracy 94.932703%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 300
# Training: Loss 0.157, Accuracy 94.860491%
# Validation: Loss 0.156, Accuracy 94.942890%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 400
# Training: Loss 0.156, Accuracy 94.904018%
# Validation: Loss 0.156, Accuracy 94.965811%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 500
# Training: Loss 0.159, Accuracy 94.795759%
# Validation: Loss 0.156, Accuracy 94.967084%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 600
# Training: Loss 0.153, Accuracy 94.985491%
# Validation: Loss 0.160, Accuracy 94.835292%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 700
# Training: Loss 0.151, Accuracy 95.084821%
# Validation: Loss 0.156, Accuracy 94.930793%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 800
# Training: Loss 0.156, Accuracy 94.838170%
# Validation: Loss 0.153, Accuracy 95.012288%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 900
# Training: Loss 0.154, Accuracy 94.985491%
# Validation: Loss 0.154, Accuracy 94.987458%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 1000
# Training: Loss 0.156, Accuracy 94.863839%
# Validation: Loss 0.156, Accuracy 94.884953%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 1100
# Training: Loss 0.154, Accuracy 94.947545%
# Validation: Loss 0.154, Accuracy 94.998918%
# Learning Rate: 0.0010000
#
# Epoch 2/10, Batch 1200
# Training: Loss 0.154, Accuracy 94.878348%
# Validation: Loss 0.154, Accuracy 95.025658%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 100
# Training: Loss 0.154, Accuracy 94.871652%
# Validation: Loss 0.156, Accuracy 94.968357%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 200
# Training: Loss 0.152, Accuracy 94.933036%
# Validation: Loss 0.154, Accuracy 94.926337%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 300
# Training: Loss 0.149, Accuracy 95.101562%
# Validation: Loss 0.155, Accuracy 94.977271%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 400
# Training: Loss 0.153, Accuracy 94.973214%
# Validation: Loss 0.154, Accuracy 94.965811%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 500
# Training: Loss 0.149, Accuracy 95.071429%
# Validation: Loss 0.153, Accuracy 94.953077%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 600
# Training: Loss 0.153, Accuracy 94.940848%
# Validation: Loss 0.152, Accuracy 94.960717%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 700
# Training: Loss 0.153, Accuracy 94.824777%
# Validation: Loss 0.154, Accuracy 94.814919%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 800
# Training: Loss 0.152, Accuracy 94.936384%
# Validation: Loss 0.153, Accuracy 94.966447%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 900
# Training: Loss 0.152, Accuracy 94.962054%
# Validation: Loss 0.155, Accuracy 94.982364%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 1000
# Training: Loss 0.153, Accuracy 94.885045%
# Validation: Loss 0.155, Accuracy 94.890046%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 1100
# Training: Loss 0.153, Accuracy 94.986607%
# Validation: Loss 0.153, Accuracy 95.028841%
# Learning Rate: 0.0010000
#
# Epoch 3/10, Batch 1200
# Training: Loss 0.151, Accuracy 95.020089%
# Validation: Loss 0.153, Accuracy 95.016108%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 100
# Training: Loss 0.149, Accuracy 94.958705%
# Validation: Loss 0.155, Accuracy 94.919333%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 200
# Training: Loss 0.148, Accuracy 95.002232%
# Validation: Loss 0.154, Accuracy 94.984911%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 300
# Training: Loss 0.149, Accuracy 95.073661%
# Validation: Loss 0.152, Accuracy 94.981727%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 400
# Training: Loss 0.152, Accuracy 94.934152%
# Validation: Loss 0.156, Accuracy 94.951167%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 500
# Training: Loss 0.145, Accuracy 95.098214%
# Validation: Loss 0.153, Accuracy 95.011014%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 600
# Training: Loss 0.145, Accuracy 95.197545%
# Validation: Loss 0.153, Accuracy 94.953077%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 700
# Training: Loss 0.148, Accuracy 94.983259%
# Validation: Loss 0.152, Accuracy 94.981091%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 800
# Training: Loss 0.153, Accuracy 94.856027%
# Validation: Loss 0.152, Accuracy 94.956897%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 900
# Training: Loss 0.147, Accuracy 95.022321%
# Validation: Loss 0.153, Accuracy 94.900870%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 1000
# Training: Loss 0.152, Accuracy 94.852679%
# Validation: Loss 0.152, Accuracy 95.002738%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 1100
# Training: Loss 0.150, Accuracy 94.934152%
# Validation: Loss 0.153, Accuracy 94.963264%
# Learning Rate: 0.0010000
#
# Epoch 4/10, Batch 1200
# Training: Loss 0.154, Accuracy 94.866071%
# Validation: Loss 0.152, Accuracy 94.975997%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 100
# Training: Loss 0.147, Accuracy 95.035714%
# Validation: Loss 0.152, Accuracy 94.994461%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 200
# Training: Loss 0.146, Accuracy 94.930804%
# Validation: Loss 0.152, Accuracy 94.932067%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 300
# Training: Loss 0.149, Accuracy 94.929688%
# Validation: Loss 0.152, Accuracy 94.968994%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 400
# Training: Loss 0.147, Accuracy 95.005580%
# Validation: Loss 0.151, Accuracy 95.006558%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 500
# Training: Loss 0.146, Accuracy 95.012277%
# Validation: Loss 0.152, Accuracy 94.968994%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 600
# Training: Loss 0.148, Accuracy 94.992188%
# Validation: Loss 0.152, Accuracy 94.985547%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 700
# Training: Loss 0.147, Accuracy 95.111607%
# Validation: Loss 0.152, Accuracy 94.959444%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 800
# Training: Loss 0.147, Accuracy 95.026786%
# Validation: Loss 0.150, Accuracy 94.965174%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 900
# Training: Loss 0.144, Accuracy 95.180804%
# Validation: Loss 0.150, Accuracy 95.001464%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 1000
# Training: Loss 0.146, Accuracy 95.052455%
# Validation: Loss 0.152, Accuracy 94.979817%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 1100
# Training: Loss 0.147, Accuracy 94.978795%
# Validation: Loss 0.152, Accuracy 94.967721%
# Learning Rate: 0.0010000
#
# Epoch 5/10, Batch 1200
# Training: Loss 0.146, Accuracy 94.996652%
# Validation: Loss 0.153, Accuracy 94.960717%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 100
# Training: Loss 0.143, Accuracy 95.117188%
# Validation: Loss 0.151, Accuracy 94.970267%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 200
# Training: Loss 0.142, Accuracy 95.106027%
# Validation: Loss 0.152, Accuracy 94.958807%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 300
# Training: Loss 0.143, Accuracy 95.116071%
# Validation: Loss 0.152, Accuracy 94.919333%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 400
# Training: Loss 0.142, Accuracy 95.104911%
# Validation: Loss 0.153, Accuracy 94.894503%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 500
# Training: Loss 0.143, Accuracy 95.091518%
# Validation: Loss 0.152, Accuracy 94.931430%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 600
# Training: Loss 0.146, Accuracy 94.977679%
# Validation: Loss 0.154, Accuracy 94.873493%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 700
# Training: Loss 0.145, Accuracy 94.996652%
# Validation: Loss 0.150, Accuracy 94.973451%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 800
# Training: Loss 0.141, Accuracy 95.189732%
# Validation: Loss 0.151, Accuracy 94.958807%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 900
# Training: Loss 0.143, Accuracy 95.051339%
# Validation: Loss 0.151, Accuracy 95.044122%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 1000
# Training: Loss 0.143, Accuracy 95.046875%
# Validation: Loss 0.152, Accuracy 94.984911%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 1100
# Training: Loss 0.148, Accuracy 94.902902%
# Validation: Loss 0.149, Accuracy 94.956897%
# Learning Rate: 0.0010000
#
# Epoch 6/10, Batch 1200
# Training: Loss 0.145, Accuracy 95.018973%
# Validation: Loss 0.151, Accuracy 94.936523%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 100
# Training: Loss 0.141, Accuracy 95.117188%
# Validation: Loss 0.152, Accuracy 94.930793%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 200
# Training: Loss 0.142, Accuracy 95.043527%
# Validation: Loss 0.151, Accuracy 94.957534%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 300
# Training: Loss 0.138, Accuracy 95.257812%
# Validation: Loss 0.153, Accuracy 94.919970%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 400
# Training: Loss 0.138, Accuracy 95.214286%
# Validation: Loss 0.155, Accuracy 94.916150%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 500
# Training: Loss 0.139, Accuracy 95.064732%
# Validation: Loss 0.152, Accuracy 95.006558%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 600
# Training: Loss 0.144, Accuracy 94.998884%
# Validation: Loss 0.153, Accuracy 94.904690%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 700
# Training: Loss 0.139, Accuracy 95.143973%
# Validation: Loss 0.152, Accuracy 94.979181%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 800
# Training: Loss 0.141, Accuracy 95.060268%
# Validation: Loss 0.153, Accuracy 94.890046%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 900
# Training: Loss 0.141, Accuracy 95.077009%
# Validation: Loss 0.152, Accuracy 94.935250%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 1000
# Training: Loss 0.141, Accuracy 95.122768%
# Validation: Loss 0.152, Accuracy 94.949257%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 1100
# Training: Loss 0.141, Accuracy 95.160714%
# Validation: Loss 0.152, Accuracy 94.923790%
# Learning Rate: 0.0010000
#
# Epoch 7/10, Batch 1200
# Training: Loss 0.138, Accuracy 95.229911%
# Validation: Loss 0.153, Accuracy 94.993188%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 100
# Training: Loss 0.139, Accuracy 95.152902%
# Validation: Loss 0.153, Accuracy 94.929520%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 200
# Training: Loss 0.136, Accuracy 95.170759%
# Validation: Loss 0.154, Accuracy 94.914877%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 300
# Training: Loss 0.136, Accuracy 95.180804%
# Validation: Loss 0.154, Accuracy 94.883679%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 400
# Training: Loss 0.137, Accuracy 95.206473%
# Validation: Loss 0.158, Accuracy 94.710504%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 500
# Training: Loss 0.138, Accuracy 95.197545%
# Validation: Loss 0.154, Accuracy 94.874766%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 600
# Training: Loss 0.140, Accuracy 95.113839%
# Validation: Loss 0.152, Accuracy 94.884316%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 700
# Training: Loss 0.136, Accuracy 95.243304%
# Validation: Loss 0.153, Accuracy 94.893230%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 800
# Training: Loss 0.135, Accuracy 95.217634%
# Validation: Loss 0.152, Accuracy 94.909146%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 900
# Training: Loss 0.134, Accuracy 95.351562%
# Validation: Loss 0.154, Accuracy 94.825105%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 1000
# Training: Loss 0.135, Accuracy 95.250000%
# Validation: Loss 0.153, Accuracy 94.861396%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 1100
# Training: Loss 0.134, Accuracy 95.257812%
# Validation: Loss 0.154, Accuracy 94.876039%
# Learning Rate: 0.0010000
#
# Epoch 8/10, Batch 1200
# Training: Loss 0.138, Accuracy 95.093750%
# Validation: Loss 0.153, Accuracy 94.851209%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 100
# Training: Loss 0.132, Accuracy 95.287946%
# Validation: Loss 0.158, Accuracy 94.799002%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 200
# Training: Loss 0.130, Accuracy 95.381696%
# Validation: Loss 0.156, Accuracy 94.809825%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 300
# Training: Loss 0.129, Accuracy 95.373884%
# Validation: Loss 0.159, Accuracy 94.741701%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 400
# Training: Loss 0.131, Accuracy 95.388393%
# Validation: Loss 0.159, Accuracy 94.629646%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 500
# Training: Loss 0.132, Accuracy 95.293527%
# Validation: Loss 0.158, Accuracy 94.904053%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 600
# Training: Loss 0.130, Accuracy 95.373884%
# Validation: Loss 0.157, Accuracy 94.819375%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 700
# Training: Loss 0.130, Accuracy 95.379464%
# Validation: Loss 0.156, Accuracy 94.789452%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 800
# Training: Loss 0.134, Accuracy 95.236607%
# Validation: Loss 0.159, Accuracy 94.823195%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 900
# Training: Loss 0.132, Accuracy 95.407366%
# Validation: Loss 0.158, Accuracy 94.804095%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 1000
# Training: Loss 0.131, Accuracy 95.306920%
# Validation: Loss 0.158, Accuracy 94.872856%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 1100
# Training: Loss 0.132, Accuracy 95.319196%
# Validation: Loss 0.157, Accuracy 94.790088%
# Learning Rate: 0.0010000
#
# Epoch 9/10, Batch 1200
# Training: Loss 0.133, Accuracy 95.297991%
# Validation: Loss 0.156, Accuracy 94.877313%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 100
# Training: Loss 0.123, Accuracy 95.654018%
# Validation: Loss 0.162, Accuracy 94.706684%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 200
# Training: Loss 0.122, Accuracy 95.554688%
# Validation: Loss 0.160, Accuracy 94.799002%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 300
# Training: Loss 0.126, Accuracy 95.474330%
# Validation: Loss 0.166, Accuracy 94.897050%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 400
# Training: Loss 0.121, Accuracy 95.561384%
# Validation: Loss 0.162, Accuracy 94.758891%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 500
# Training: Loss 0.125, Accuracy 95.457589%
# Validation: Loss 0.165, Accuracy 94.813645%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 600
# Training: Loss 0.126, Accuracy 95.418527%
# Validation: Loss 0.162, Accuracy 94.667210%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 700
# Training: Loss 0.122, Accuracy 95.583705%
# Validation: Loss 0.160, Accuracy 94.697770%
# Learning Rate: 0.0010000
#
# Epoch 10/10, Batch 800
# Training: Loss 0.126, Accuracy 95.408482%
# Validation: Loss 0.162, Accuracy 94.586352%
# Learning Rate: 0.0010000

# %% [markdown]
# # 5. Evaluate Model
# You will need to setup an evaluation loop for the model to assess it's performance on the test dataset.
#
# You may also obtain a classification report after final evaluation of the test dataset with the model using the code below. A confusion matrix can also be obtained and we will plot a few example images.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=classes))

# %% [markdown]
#  # Comments about your Approach
